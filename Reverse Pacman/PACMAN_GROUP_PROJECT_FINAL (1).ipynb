# %% [markdown]
# # Project by:
#
# Aaditya Kumar Yadav <br>
# Adeday Gebreyohans  <br>
# Ahunna Ike-Njoku Theresa <br>
# Hermela Gelan <br>
# Jiachen Tu <br>
# Kanchan Lama <br>
# Nishant Gurung <br>
# Sylvester Duah <br>

# %%
# graphics, time, random: default 
# bind_keys: custom class

# I: user's movement 
# P: checks if the user and the pac-man, or the pac-kids have the same co-ordinates
#   checks if the pacman collides with one of the walls
# O: stops the game if the user and the pacman collide 
#   removes the pac-kids as the user moves through them
#   resets the pacman's movement if it collides with one of the walls 

import graphics
import bind_keys
import time
import random
 
def chioce(): #In the choice equation, the computer randomly selects one of four directions: "up", "down", "left" or "right"
    dir = ["up", "down", "left","right"]
    return random.choices(dir)[0]

def direction():  #In the direction equation, the computer converts the result of the choice equation into the motion direction of the image in the "graphics".
    c = chioce()
    if c == "left":
        a = -2
        b = 0
    elif c == "right":
        a = 2
        b = 0
    elif c == "up":
        a = 0
        b = -2
    else:
        a = 0
        b = 2
    return a,b
def draw_rectangle(x,y,x2,y2,color,o_color,win):
    r=graphics.Rectangle(graphics.Point(x,y),graphics.Point(x2,y2))
    r.setFill(color)
    r.setOutline(o_color)
    r.draw(win)
def draw_circle(x,y,r,color,o_color,win):
    c= graphics.Circle(graphics.Point(x,y),r)
    c.setFill(color) #fill the circle with color
    c.setOutline(o_color) #use diff color outline
    c.draw(win)
    
#     fa = graphics.Circle(graphics.Point(60,60),2.5)
#     fa.setFill("yellow") 
#     fa.draw(win) 
    

# def images(): 
#     #win = graphics.GraphWin("Pacman", 700, 600)
#     #the points on the upper left straight  
#     draw_circle(60,60,2.5,"yellow","yellow",win)
#     draw_circle(60,120,2.5,"yellow","yellow",win)
#     draw_circle(60,180,2.5,"yellow","yellow",win)
#     draw_circle(60,240,2.5,"yellow","yellow",win)
    
#draw the overall map of the game
   
def main():  
    win = graphics.GraphWin("Pacman", 700, 600)
    win.setBackground("black")
    draw_rectangle(0,500,700,600,"tan","tan",win)
    draw_rectangle(0,0,700,30,"gray","gray",win) #longer rectangle on the upper end
    draw_rectangle(0,0,30,500,"gray","gray",win) #upper left rectangle
    draw_rectangle(670,0,700,500,"gray","gray",win) #upper right rectangle
    draw_rectangle(0,470,700,500,"gray","gray",win) #longer lower end rectangle
   
    draw_rectangle(100,350,300,380,"gray","gray",win) #lower floating rectangle on the left
    draw_rectangle(200,100,600,130,"gray","gray",win) #second upper longer rectangle
    draw_rectangle(200,200,500,230,"gray","gray",win) #below the second upper longer rectangle
    draw_rectangle(470,200,500,300,"gray","gray",win) #upper small right straight
    draw_rectangle(570,380,600,500,"gray","gray",win) #right lower straight rectangle
    draw_rectangle(90,130,130,300,"gray","gray",win)
    
 
 #   draw_circle(320,260,2.5,"yellow","yellow",win)

    #draw_circle(60,440,2.5,"yellow","yellow",win)
 
    # draw_circle(640,440,2.5,"yellow","yellow",win)
    #draw_circle(630,60,2.5,"yellow","yellow",win)
    
    # fa = draw_circle(60,60,2.5,"yellow","yellow",win)
    # pel2 = draw_circle(60,120,2.5,"yellow","yellow",win)
    # pel3 = draw_circle(60,180,2.5,"yellow","yellow",win)
    # pel4 = draw_circle(60,240,2.5,"yellow","yellow",win)
    
    
    # creating the pac-kids 
    
    fa = graphics.Circle(graphics.Point(60,60),2.5)
    fa.setFill("yellow") 
    fa.draw(win) 
    pax = fa.getCenter()
    
    ma = graphics.Circle(graphics.Point(320,260),2.5)
    ma.setFill("yellow") 
    ma.draw(win) 
    eax = ma.getCenter()
    
    ga = graphics.Circle(graphics.Point(630,60),2.5)
    ga.setFill("yellow") 
    ga.draw(win) 
    dax = ga.getCenter()
    
    na = graphics.Circle(graphics.Point(640,440),2.5)
    na.setFill("yellow") 
    na.draw(win) 
    jax = na.getCenter()
    
    pa = graphics.Circle(graphics.Point(60,440),2.5)
    pa.setFill("yellow") 
    pa.draw(win) 
    uax = pa.getCenter()
    
    
       
        
    
#     c1 = graphics.Circle(graphics.Point(60,60), 2.5)
#     c1.setFill("yellow") # set the color of a shape
#     c1.draw(win)   
#     for i in range(10):
        
#         c1.move(-1000,-1000) # move 5 to the right and 5 down
#         time.sleep(.05)
#     def eat():
         # if g.getX() == fa.getX(): 
         #    fa = graphics.Circle(graphics.Point(-1000,-1000),2.5) 
         #    fa.setFill("yellow") 
         #    fa.draw(win) 
#     eat()
    
    #pel1x = pel1.getCenter()
   
    #drawing a pacman
    pacman = graphics.Circle(graphics.Point(430,260),25)
    pacman.setFill("skyblue")
    pacman.draw(win)
    
   
    #drawing a ghost
    ghost = graphics.Circle(graphics.Point(420,420), 25)
    ghost.setFill("blue")
    p1 = bind_keys.Player(win, ghost)
    p1.create()

    

#     while not win.isClosed(): 
#         g = ghost.getCenter()
#         pelx = fa.getCenter() 
        
#         if g.getCenter() == fa.getCenter(): 
#             pel1 = (-1000,-1000,2.5,"yellow", "yellow", win) 

    
   
    example_text = "WELCOME TO REVERSE PACMAN!\n EAT THE PAC-KIDS BEFORE THE PACMAN GETS YOU!!"
    t = graphics.Text(graphics.Point(300,550), example_text)
    t.draw(win)
    

    while not win.isClosed():
        for i in range(5):
            x1,y1 = direction()
            while x1+y1 != 0:
                p = pacman.getCenter() # gets the center point of the pacman
                
                g = ghost.getCenter() # gets the center point of the ghost 
                    
                pacman.move(x1,y1)
                time.sleep(.05)
                p1.movement()
                win.update()
                time.sleep(.05)
                
                #The following code is used to make the ghost hit the wall after re-choose the direction
                #First, write a condition based on the position of each wall to determine that the circle hit the wall
                #When the pacman hit the walls its x1 and y1 would be 0. That means it would stop.
                #Then the pacman will move to the opposite direction. Otherwise, it will continue to trigger collision judgments
                #then one loop finished and the next loop begins
                
                
                if p.getX() - 25 < 30:
                    x1 = 0
                    y1 = 0
                    for i in range(2):
                        pacman.move(2,0)
                        time.sleep(.05)
                               
           
                if p.getY() + 25 > 470:
                    x1 = 0
                    y1 = 0
                    for i in range(2):
                        pacman.move(0,-2)
                        time.sleep(.05)
                   
                if p.getX() +25 >670:
                    x1 = 0
                    y1 = 0
                    for i in range(2):
                        pacman.move(-2,0)
                        time.sleep(.05)
                   
                if p.getY() -25 <30:
                    x1 = 0
                    y1 = 0
                    for i in range(2):
                        pacman.move(0,2)
                        time.sleep(.05)
                   
                if p.getX() +25 >200:
                    if p.getX() -25 <500:
                        if p.getY() -25 <230:
                            if p.getY() - 25 >200:
                                x1 = 0
                                y1 = 0
                                for i in range(2):
                                    pacman.move(0,2)
                                    time.sleep(.05)
                   
                   
                if p.getX() +25 >200:
                    if p.getX() -25 <600:
                        if p.getY() -25 < 130:
                            if p.getY() - 25 >100:
                                x1 = 0
                                y1 = 0
                                for i in range(2):
                                    pacman.move(0,2)
                                    time.sleep(.05)
                   
           
                if p.getX() -25 >100:
                    if p.getX() +25 <300:
                        if p.getY() -25 < 380:
                            if p.getY() - 25 >350:
                                x1 = 0
                                y1 = 0
                                for i in range(2):
                                    pacman.move(0,2)
                                    time.sleep(.05)
           
                if p.getX() -25 >100:
                    if p.getX() +25 <300:
                        if p.getY() +25 < 380:
                            if p.getY() + 25 >350:
                                x1 = 0
                                y1 = 0
                                for i in range(2):
                                    pacman.move(0,-2)
                                    time.sleep(.05)
                   
                   
                if p.getX() +25 >470:
                    if p.getX() +25 <500:
                        if p.getY() - 25 > 230:
                            if p.getY() + 25 < 300:
                                x1 = 0
                                y1 = 0
                                for i in range(2):
                                    pacman.move(-2,0)
                                    time.sleep(.05)
                               
                if p.getX() -25 >470:
                    if p.getX() -25 <500:
                        if p.getY() - 25 > 230:
                            if p.getY() + 25 < 300:
                                x1 = 0
                                y1 = 0
                                for i in range(2):
                                    pacman.move(-2,0)
                                    time.sleep(.05) #changed from 4
                                       
                   
                   
                if p.getX() +25 <600:
                    if p.getX() +25 >570:
                        if p.getY() -25 >380:
                            x1 = 0
                            y1 = 0
                            for i in range(2):
                                pacman.move(-2,0)
                                time.sleep(.05)
                           
                if p.getX() -25 <600:
                    if p.getX() -25 >570:
                        if p.getY() -25 >380:
                            x1 = 0
                            y1 = 0
                            for i in range(2):
                                pacman.move(2,0)
                                time.sleep(.05)
           
           

                               
                if p.getX() -25 >90:
                    if p.getX() -25 <130:
                        if p.getY() - 25 > 130:
                            if p.getY() + 25 < 300:
                                x1 = 0
                                y1 = 0
                                for i in range(2):
                                    pacman.move(2,0)
                                    time.sleep(.05)           
                                    
                                    
                           
#          #c1 = graphics.Circle(graphics.Point(60,60), 2.5)
#             #pax = c1.getCenter
#             c1.setFill("yellow") # set the color of a shape
#             c1.draw(win)   
#             for i in range(10):
#                 if g.getX() == c1.getP1(): 
#                     c1.move(-1000,-1000) # move 5 to the right and 5 down
#                     #time.sleep(.05)
                # if g.getX() - 25 < 30:
                #     print("HERE")
                #     p1.block()
                #     print(win.lastKey)
                    
                    # if (win.lastKey != "s" and win.lastKey != "a"):
                    #     p1.movement()

                    
                # checks to see if the user(ghost) and the packids are in the same spot 
                # if statements allow us to create a condition to check if they have the same co-ordinates
                # and then erases the pac-kids if the user moves through them
                
                
                
                if g.getX()-25 < 60 and g.getX()+25 > 60 and g.getY()-25 < 60 and g.getY()+25 > 60:
                    # fa = graphics.Circle(graphics.Point(80,80), 2.5)
                    #fa.setFill("red") 
                    fa.undraw()
                    #fa.draw(win) 
                    #print(fa)
                    #print("It hit!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!")
                    
                if g.getX()-25 < 320 and g.getX()+25 > 320 and g.getY()-25 < 260 and g.getY()+25 > 260:
                    # fa = graphics.Circle(graphics.Point(80,80), 2.5)
                    #fa.setFill("red") 
                    ma.undraw()
                    
                if g.getX()-25 < 630 and g.getX()+25 > 630 and g.getY()-25 < 60 and g.getY()+25 > 60:
                    # fa = graphics.Circle(graphics.Point(80,80), 2.5)
                    #fa.setFill("red") 
                    ga.undraw()
                    
                if g.getX()-25 < 640 and g.getX()+25 > 640 and g.getY()-25 < 440 and g.getY()+25 > 440:
                    # fa = graphics.Circle(graphics.Point(80,80), 2.5)
                    #fa.setFill("red") 
                    na.undraw()
                    
                if g.getX()-25 < 60 and g.getX()+25 > 60 and g.getY()-25 < 440 and g.getY()+25 > 440:
                    # fa = graphics.Circle(graphics.Point(80,80), 2.5)
                    #fa.setFill("red") 
                    pa.undraw()
           
        
        
        
        # condition to check if the ghost and the pacman are in the same spot, somewhere in the map 
        # stops the game and print GAME OVER if true. 
        
        
        
        
                if p.getX()-25 < g.getX() and p.getX()+25 > g.getX() and p.getY()-25 < g.getY() and p.getY()+25 > g.getY():
                    print("GAME OVER!!") 
                    win.close()
                    
                
main()
# Out:
# GAME OVER!!
# GAME OVER!!
# GAME OVER!!
# GAME OVER!!

# %%
# c1 = graphics.Circle(graphics.Point(60,60), 2.5)
                # #pax = c1.getCenter
                # c1.setFill("yellow") # set the color of a shape
                # c1.draw(win)   
                 # for i in range(10):
                 #    if g.getX() == c1.getP1 (): 
                 #        c1.move(-1000,-1000) # move 5 to the right and 5 down
                 #        time.sleep(.05)
    # def eat():
                # if g.getX() == pax.getX(): 
                #     fa = canvas.delete(fa)
                    #fa = graphics.Circle((-1000,-1000),2.5) 
                    # fa = graphics.Circle(graphics.Point(-1000,-1000),2.5) 
                    # fa.setFill("yellow") 
                    # fa.draw(win) 
    # eat()
    
                    #win.close()
    
#                 def eat():  
            
#                     pax = fa.getCenter()

#                     if p.getX()+25 == fa.getCenter(): 
#                         pax = graphics.Circle(graphics.Point(-1000,-1000),2.5) 
#                         pax.setFill("yellow") 
#                         pax.draw(win) 
#                 eat()


# def eat(): 
#     fa = graphics.Circle(graphics.Point(60,60),2.5)
#     fa.setFill("yellow") 
#     fa.draw(win) 
    
#     pax = fa.getCenter()
        
#     if g == pax: 
#         fa = graphics.Circle(graphics.Point(-1000,-1000),2.5) 
#         fa.setFill("yellow") 
#         fa.draw(win) 
# eat()
            
#     if p.getX()+25 == fa.getCenter(): 
#         pax = graphics.Circle(graphics.Point(-1000,-1000),2.5) 
#         pax.setFill("yellow") 
#         pax.draw(win) 
                    
                       #the points on the upper left straight  
#     def pellets(): 

#         draw_circle(60,60,2.5,"yellow","yellow",win)
#         draw_circle(60,120,2.5,"yellow","yellow",win)
#         draw_circle(60,180,2.5,"yellow","yellow",win)
#         draw_circle(60,240,2.5,"yellow","yellow",win)


#     pellets()
    #win.getMouse()
    #win.close()
#images()
